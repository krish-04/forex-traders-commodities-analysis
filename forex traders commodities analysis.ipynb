# %% [markdown]
# # Forex traders Commodities Analysis

# %% [markdown]
# # project by: KRISHNA PATIL

# %% [markdown]
# #  Project for Datascience and Machine learning Internship
# ##Welcome!
#
# Investment Bankers. CA's Hedge Fund / Portfolio Managers. Forex traders Commodities Analysts These have been historically considered to be among the most coveted professions of all time. Yet it one fails to keep up with the demands of the day, one would find one's skills to be obsolete in this era of data analysis.
#
# Data Science has inarguably been the hottest domain of the decade, asserting its need in every single sphere of corporate life. It was not long ago when we discovered the massive potential of incorporating ML/A in the financial world Now, the very idea of the two being disjointed sounds strange
#
# Data Science has been incremental in providing powerful insights ( which people didn't even know existed) and helped massively increase efficiency, helping everyone from a scalp trader to a long term debt investor. Accurate predictions, unbiased analysis, powerful tools that run through millions of rows of data in the blink of an eye have transformed the industry in ways we could've never imagined
#
# The following program is designed to both test your knowledge and to give you the feel and experience of a real-world financial world - data science problem.

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# # 1.1 Import the csv file of the stock using “pd.read_csv” function into dataframe. Analyze and understand each column properly. Use head(), tail(), describe() functions for exploration.

# %%
import pandas as pd    # It provides high-performance, easy to use structures and data analysis tools
import numpy as np     # provides objects for multi-dimensional arrays
import seaborn as sns  # provides a high-level interface for drawing attractive and informative statistical graphics, data visualization library
import matplotlib.pyplot as plt
import plotly.graph_objects as go  #unique chart types covering a wide range of statistical, financial, geographic, scientific, and 3-dimensional use-cases.
import plotly.express as px

# %%
df=pd.read_csv('IDBI.csv') #reading the data file

# %%
df #displays the data file
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     IDBI     EQ  15-May-2017       75.50       75.70       76.10      73.15
# 1     IDBI     EQ  16-May-2017       75.05       75.30       77.75      73.85
# 2     IDBI     EQ  17-May-2017       76.65       76.65       77.30      75.60
# 3     IDBI     EQ  18-May-2017       75.95       75.00       75.50      69.05
# 4     IDBI     EQ  19-May-2017       69.95       69.00       70.95      68.50
# ..     ...    ...          ...         ...         ...         ...        ...
# 489   IDBI     EQ  07-May-2019       38.60       38.70       38.95      37.05
# 490   IDBI     EQ  08-May-2019       37.25       37.40       37.55      36.75
# 491   IDBI     EQ  09-May-2019       37.05       36.65       37.75      36.65
# 492   IDBI     EQ  10-May-2019       37.45       37.60       38.40      36.75
# 493   IDBI     EQ  13-May-2019       37.25       37.15       37.15      34.25
#
# ...

# %%
df.columns #displays the columns name that are present in the dataframe
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty'],
#       dtype='object')

# %%
df.head() #displays the top five rows of the dataframe
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   IDBI     EQ  15-May-2017       75.50       75.70       76.10      73.15
# 1   IDBI     EQ  16-May-2017       75.05       75.30       77.75      73.85
# 2   IDBI     EQ  17-May-2017       76.65       76.65       77.30      75.60
# 3   IDBI     EQ  18-May-2017       75.95       75.00       75.50      69.05
# 4   IDBI     EQ  19-May-2017       69.95       69.00       70.95      68.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       75.25        75.05          74.58                6688622
# 1       77.05        76.65          75.38                8740098
# 2       75.75        75.95          76.37                3152912
# 3       69.05        69.95          71.46               15086266
# 4       68.70        68.75          69.42               10966153
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df.tail() #displays the bottom five rows of the dataframe
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 489   IDBI     EQ  07-May-2019       38.60       38.70       38.95      37.05
# 490   IDBI     EQ  08-May-2019       37.25       37.40       37.55      36.75
# 491   IDBI     EQ  09-May-2019       37.05       36.65       37.75      36.65
# 492   IDBI     EQ  10-May-2019       37.45       37.60       38.40      36.75
# 493   IDBI     EQ  13-May-2019       37.25       37.15       37.15      34.25
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489       37.20        37.25          37.99                4301722
# 490       37.10        37.05          37.11                3990622
# 491       37.45        37.45          37.22                4172940
# 492       36.85        37.25          37.62                5233900
# 493       34.35        34.45          35.58                6277464
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df.describe() #checking for statistical summary such as count,mean,etc. of numeric columns
# Out:
#        Prev Close  Open Price  High Price   Low Price  Last Price  \
# count  494.000000  494.000000  494.000000  494.000000  494.000000
# mean    58.529960   58.628441   59.698684   57.345243   58.422571
# std      8.132574    8.131273    8.514477    7.808250    8.150144
# min     37.050000   36.650000   37.150000   34.250000   34.350000
# 25%     55.187500   55.300000   56.162500   53.800000   55.162500
# 50%     59.450000   59.600000   60.375000   58.700000   59.500000
# 75%     62.000000   62.037500   63.050000   61.137500   61.950000
# max     84.650000   85.500000   91.500000   79.850000   84.150000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count   494.000000     494.000000           4.940000e+02  4.940000e+02
# mean     58.446862      58.533968           1.144775e+07  7.230566e+08
# std       8.168467       8.165891           1.570200e+07  1.152630e+09
# min      34.450000      35.580000           2.693910e+05  1.604167e+07
# ...

# %%
df.dtypes #checking the datatypes of different columns of the dataframe
# Out:
# Symbol                     object
# Series                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                float64
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover                  float64
# No. of Trades               int64
# Deliverable Qty             int64
# % Dly Qt to Traded Qty    float64
# dtype: object

# %%
df.info()  #getting the information of dataframe such as no. of entries,data columns,non-null count,data types,etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  494 non-null    object
#  1   Series                  494 non-null    object
#  2   Date                    494 non-null    object
#  3   Prev Close              494 non-null    float64
#  4   Open Price              494 non-null    float64
#  5   High Price              494 non-null    float64
#  6   Low Price               494 non-null    float64
#  7   Last Price              494 non-null    float64
#  8   Close Price             494 non-null    float64
#  9   Average Price           494 non-null    float64
#  10  Total Traded Quantity   494 non-null    int64
#  11  Turnover                494 non-null    float64
#  12  No. of Trades           494 non-null    int64
#  13  Deliverable Qty         494 non-null    int64
# ...

# %%
df.shape  #shape of the dataframe ie no. of rows and columns
# Out:
# (494, 15)

# %% [markdown]
# # 1.2 Calculate the minimum, maximum, mean price for the column “Close Price” using pandas library.

# %%
minvalue=df['Close Price'].min()  #gives the minimum value in the dataframe of Close Price column
print("minimum value in column 'Close Price': " , minvalue)
# Out:
# minimum value in column 'Close Price':  34.45

# %%
maxvalue=df['Close Price'].max()   #gives the maximum value in the dataframe of Close Price column
print("maximum value in column 'Close Price': " , maxvalue)
# Out:
# maximum value in column 'Close Price':  84.65

# %%
df.loc[:,"Close Price"].mean()  #gives the mean value in the dataframe of Close Price column
# Out:
# 58.44686234817817

# %% [markdown]
# # 1.3 Add a column "Day Perc Change where the values are the daily change in percentage i.e. the percentage change between 2 consecutive days closing prices. Instead of using the basic mathematical formula for computing the same, use 'pct_change()' function provided by Pandas for dataframes. You will note that the first entry of the column will have a 'Nan' value. Remove the first row.

# %%
#Start code
df['Day_Perc_Change'] = df['Close Price'].pct_change()*100  #finds the percentage difference between 2 consecutive days
#End code

# %%
df
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     IDBI     EQ  15-May-2017       75.50       75.70       76.10      73.15
# 1     IDBI     EQ  16-May-2017       75.05       75.30       77.75      73.85
# 2     IDBI     EQ  17-May-2017       76.65       76.65       77.30      75.60
# 3     IDBI     EQ  18-May-2017       75.95       75.00       75.50      69.05
# 4     IDBI     EQ  19-May-2017       69.95       69.00       70.95      68.50
# ..     ...    ...          ...         ...         ...         ...        ...
# 489   IDBI     EQ  07-May-2019       38.60       38.70       38.95      37.05
# 490   IDBI     EQ  08-May-2019       37.25       37.40       37.55      36.75
# 491   IDBI     EQ  09-May-2019       37.05       36.65       37.75      36.65
# 492   IDBI     EQ  10-May-2019       37.45       37.60       38.40      36.75
# 493   IDBI     EQ  13-May-2019       37.25       37.15       37.15      34.25
#
# ...

# %%
df.dropna(axis = 0, inplace = True) #used to drop the first row with NaN value

# %%
df
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 1     IDBI     EQ  16-May-2017       75.05       75.30       77.75      73.85
# 2     IDBI     EQ  17-May-2017       76.65       76.65       77.30      75.60
# 3     IDBI     EQ  18-May-2017       75.95       75.00       75.50      69.05
# 4     IDBI     EQ  19-May-2017       69.95       69.00       70.95      68.50
# 5     IDBI     EQ  22-May-2017       68.75       69.00       69.60      65.75
# ..     ...    ...          ...         ...         ...         ...        ...
# 489   IDBI     EQ  07-May-2019       38.60       38.70       38.95      37.05
# 490   IDBI     EQ  08-May-2019       37.25       37.40       37.55      36.75
# 491   IDBI     EQ  09-May-2019       37.05       36.65       37.75      36.65
# 492   IDBI     EQ  10-May-2019       37.45       37.60       38.40      36.75
# 493   IDBI     EQ  13-May-2019       37.25       37.15       37.15      34.25
#
# ...

# %% [markdown]
# # 1.4 Convert the Date column into the type datetime64 and plot the closing price of each of the days for the entire time frame to get an idea of what the general outlook of the stock is.

# %%
df['Date'] = pd.to_datetime(df['Date'])  #converts the date column values into the standard format of type datetime64

# %%
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 1     IDBI     EQ 2017-05-16       75.05       75.30       77.75      73.85
# 2     IDBI     EQ 2017-05-17       76.65       76.65       77.30      75.60
# 3     IDBI     EQ 2017-05-18       75.95       75.00       75.50      69.05
# 4     IDBI     EQ 2017-05-19       69.95       69.00       70.95      68.50
# 5     IDBI     EQ 2017-05-22       68.75       69.00       69.60      65.75
# ..     ...    ...        ...         ...         ...         ...        ...
# 489   IDBI     EQ 2019-05-07       38.60       38.70       38.95      37.05
# 490   IDBI     EQ 2019-05-08       37.25       37.40       37.55      36.75
# 491   IDBI     EQ 2019-05-09       37.05       36.65       37.75      36.65
# 492   IDBI     EQ 2019-05-10       37.45       37.60       38.40      36.75
# 493   IDBI     EQ 2019-05-13       37.25       37.15       37.15      34.25
#
# ...

# %%
df['Close Price'].plot(figsize = (15,8))
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(figsize=(12,7))
ax.scatter(df['Date'],df['Close Price'])
ax.set_xlabel('Close Price')
ax.set_ylabel('Date')
plt.show()

# %% [markdown]
# # 1.5 A stem plot  is a discrete series plot,ideal for plotting daywise data.It can be plotted using the plt.stem() function.Display a stem plot of the daily change in the stock price in percentage.

# %%
plt.stem(df['Date'],df['Day_Perc_Change'])
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# it was observed that whenever the volume of shares traded is high, there is comparatively high rise or fall in the price of the stock leading to the high returns. Thus, on a given day if unconventionally high volume of trading takes place, then one can expect a big change in the market in the either direction. Volume of shares traded when coupled with the rise or fall in Price of stock, in general, is an indicator of the confidence of the traders & investors in a particular company.

# %% [markdown]
# # 1.6 Plot of the daily return(percentage) distribution as a histogram.Output is a frequency plot of various values of percentage changes.

# %%
df['Day_Perc_Change'].plot(figsize = (12, 6), fontsize = 12)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It can be observed that for most of the days, the returns are between -5% to 5% with few spikes in between crossing 5% mark on both the sides.

# %%
df['Day_Perc_Change'].hist(bins = 50, figsize = (10,5)) 
plt.xlabel('Daily returns')
plt.ylabel('Frequency')
plt.show()
#satistics
df.Day_Perc_Change.describe()
# Out:
# count    493.000000
# mean      -0.117464
# std        2.858591
# min       -8.274399
# 25%       -1.444350
# 50%       -0.115340
# 75%        1.062960
# max       19.981584
# Name: Day_Perc_Change, dtype: float64

# %% [markdown]
# The daily returns histogram is centered about origin. For the past 2 years, the mean daily returns has been about 0.117 and for most of the days the daily return was less than 1% implying that the df stock has been less volatile over the period. During the period, the highest % change in positive direction was observed to be 19.98% and was 8.27% in negative direction. Clearly, we didn’t had any instances of ‘bull run’ or ‘bear drop’!
